# %% [markdown]
# <a href="https://colab.research.google.com/github/AlenaAntipina/PytorchLearning/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import zipfile
import os

# %%
zip_ref = zipfile.ZipFile('/content/observations-master.zip', 'r') #Opens the zip file in read mode
zip_ref.extractall('/content/tmp') #Extracts the files into the /tmp folder
zip_ref.close()
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-58-f7d99c521a81> in <module>
# ----> 1 zip_ref = zipfile.ZipFile('/content/observations-master.zip', 'r') #Opens the zip file in read mode
#       2 zip_ref.extractall('/content/tmp') #Extracts the files into the /tmp folder
#       3 zip_ref.close()
#
# /usr/lib/python3.7/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1256         try:
#    1257             if mode == 'r':
# -> 1258                 self._RealGetContents()
#    1259             elif mode in ('w', 'x'):
#    1260                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.7/zipfile.py in _RealGetContents(self)
#    1323             raise BadZipFile("File is not a zip file")
#    1324         if not endrec:
# -> 1325             raise BadZipFile("File is not a zip file")
#    1326         if self.debug > 1:
#    1327             print(endrec)
#
# BadZipFile: File is not a zip file

# %%
# !wget --no-check-certificate \
    "https://github.com/prajnasb/observations/observations-master.zip" \
    -O "/tmp/people.zip"


zip_ref = zipfile.ZipFile('/tmp/people.zip', 'r') #Opens the zip file in read mode
zip_ref.extractall('/tmp') #Extracts the files into the /tmp folder
zip_ref.close()
# Out:
# --2022-10-27 13:51:40--  https://github.com/prajnasb/observations/observations-master.zip
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2022-10-27 13:51:41 ERROR 404: Not Found.
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-56-7fddefc24187> in <module>
#       2
#       3
# ----> 4 zip_ref = zipfile.ZipFile('/tmp/people.zip', 'r') #Opens the zip file in read mode
#       5 zip_ref.extractall('/tmp') #Extracts the files into the /tmp folder
#       6 zip_ref.close()
#
# /usr/lib/python3.7/zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1256         try:
#    1257             if mode == 'r':
# -> 1258                 self._RealGetContents()
#    1259             elif mode in ('w', 'x'):
#    1260                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.7/zipfile.py in _RealGetContents(self)
#    1323             raise BadZipFile("File is not a zip file")
#    1324         if not endrec:
# -> 1325             raise BadZipFile("File is not a zip file")
#    1326         if self.debug > 1:
#    1327             print(endrec)
#
# BadZipFile: File is not a zip file

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/gdrive/MyDrive/Classificator/dataset.zip ../

# %%
# !unzip ../dataset.zip -d data/

# %%
#import pathlib
#dataset_url = 'data/dataset/images'
#data_dir = tf.keras.utils.get_file('people_photos', origin=dataset_url, untar=True)
#data_dir = pathlib.Path(data_dir)

# %%
data_dir = 'data/dataset/images'

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
import matplotlib.pyplot as plt

# %%
import pathlib
from pathlib import Path
import os

import natsort

import cv2
from PIL import Image

# %%
without_mask_filenames = os.listdir(data_dir)
without_mask_filenames = natsort.natsorted(without_mask_filenames)

with_mask_filenames = os.listdir(data_dir)
with_mask_filenames = natsort.natsorted(with_mask_filenames)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-52-46782ce6384e> in <module>
# ----> 1 without_mask_filenames = os.listdir(data_dir)
#       2 without_mask_filenames = natsort.natsorted(without_mask_filenames)
#       3
#       4 with_mask_filenames = os.listdir(data_dir)
#       5 with_mask_filenames = natsort.natsorted(with_mask_filenames)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'https://github.com/prajnasb/observations/tree/master/experiements/data'

# %%
pic_box = plt.figure(figsize=(14,12))
for i, image_name in enumerate(with_mask_filenames[5:15]):
  image = plt.imread(str(Path('data/dataset/images/with_mask', image_name)))
  ax = pic_box.add_subplot(3,5,i+1)
  ax.set_title(str(image_name) + '\n Каналов = ' + str(image.shape[2]))
  plt.imshow(image)
  plt.axis('off')
plt.show()

# %%
for img in with_mask_filenames:
  im = Image.open(Path('data/dataset/images/with_mask', img))
  if (img[-3:].lower()=='png' and im.format is 'PNG'):
    if (im.mode is not 'RGBA'):
      im.convert("RGBA").save(Path('data/dataset/images/with_mask', img))
      print(img)
# Out:
# maksssksksss0.png
# maksssksksss6.png
# maksssksksss84.png
# maksssksksss106.png
# maksssksksss142.png
# maksssksksss165.png
# maksssksksss230.png
# maksssksksss340.png
# maksssksksss346.png
# maksssksksss366.png
# maksssksksss373.png
# maksssksksss446.png
# maksssksksss506.png
# maksssksksss525.png
# maksssksksss550.png
# maksssksksss573.png
# maksssksksss592.png
# maksssksksss659.png
# maksssksksss702.png
# maksssksksss717.png
# maksssksksss788.png
# maksssksksss813.png

# %%
for img in without_mask_filenames:
  im = Image.open(Path('data/dataset/images/without_mask', img))
  if (img[-3:].lower()=='png' and im.format is 'PNG'):
    if (im.mode is not 'RGBA'):
      im.convert("RGBA").save(Path('data/dataset/images/without_mask', img))
      print(img)
# Out:
# maksssksksss340.png
# maksssksksss717.png

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 947 files belonging to 2 classes.
# Using 758 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 947 files belonging to 2 classes.
# Using 189 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['with_mask', 'without_mask']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
num_classes = len(class_names)

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, name="outputs")
])

# %%
checkpoint_filepath = 'best_model.h5'

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    monitor='val_binary_accuracy',
    mode='max',
    save_best_only=True)

# %%
epochs = 10

# %%
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
img = tf.keras.utils.load_img(
    '/content/without2.jpg', target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 180ms/step
# This image most likely belongs to with_mask with a 100.00 percent confidence.
